# %% [markdown]
# # "[속보]", 180일(매일), 관련도순, 상위20개 기사

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# ChromeDriver 경로 설정
driver_path = "/Users/leesangwon/Desktop/chromedriver-mac-arm64/chromedriver"  # 여기에 ChromeDriver의 경로를 입력
service = Service(driver_path)

# 웹드라이버 초기화
driver = webdriver.Chrome(service=service)

# %% [markdown]
# ### 테스트

# %%
# 한글 인코딩
import urllib.parse

text = "[속보]"

# URL 인코딩
encoded_text = urllib.parse.quote(text)

year = "2024"
month = "02"
start_d = "15"
end_d = "31"


# 정렬 옵션 sort=0 : 관련도순    sort=1 : 최신순    sort=2 : 오래된순             # 언론사 옵션 mynews=0 : 전체    mynews=1 : 일간지
# 오래된순 정렬, 일간지 언론사
# url = f"https://search.naver.com/search.naver?where=news&query={encoded_text}&sm=tab_opt&sort=2&photo=0&field=0&pd=3&ds={year}.{month}.{start_d}&de={year}.{month}.{end_d}&docid=&related=0&mynews=1&office_type=3&office_section_code=0&news_office_checked=&nso=so%3Ar%2Cp%3Afrom{year}{month}{start_d}to{year}{month}{end_d}&is_sug_officeid=0&office_category=1&service_area=0"
# 관련도순 정렬, 전체 언론사
url = f"https://search.naver.com/search.naver?where=news&query={encoded_text}&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds={year}.{month}.{start_d}&de={year}.{month}.{end_d}&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Ar%2Cp%3Afrom{year}{month}{start_d}to{year}{month}{end_d}&is_sug_officeid=0&office_category=0&service_area=0"


print(url)


# 웹사이트 열기
driver.get(url)
# Out:
# https://search.naver.com/search.naver?where=news&query=%5B%EC%86%8D%EB%B3%B4%5D&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds=2024.02.15&de=2024.02.31&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Ar%2Cp%3Afrom20240215to20240231&is_sug_officeid=0&office_category=0&service_area=0

# %% [markdown]
# ### 최종 월별 크롤링 코드

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import urllib.parse
import time
import pandas as pd

# 데이터프레임 리스트 초기화
all_data = []

#####################################################
# 검색어, 연도, 월 설정
text = "[속보]"
year = ['2024']
month = ['05']
#####################################################

# ChromeDriver 경로 설정
driver_path = "/Users/leesangwon/Desktop/chromedriver-mac-arm64/chromedriver"  # 여기에 ChromeDriver의 경로를 입력
service = Service(driver_path)

# 웹드라이버 초기화
driver = webdriver.Chrome(service=service)

# 연도, 월을 순회하며 크롤링
for y in year:
    for m in month:
        # 월의 마지막 날짜 계산
        if m == '01' or m == '03' or m == '05' or m == '07' or m == '08' or m == '10' or m == '12':
            last_day = 31
        elif m == '04' or m == '06' or m == '09' or m == '11':
            last_day = 30
        else:  # 2월 (윤년은 29일)
            last_day = 29

        # 하루 단위로 크롤링
        for day in range(1, last_day + 1):
            start_d = str(day).zfill(2)  # 01, 02, ..., 31 형태로 만들어줌
            end_d = start_d  # 하루 단위로 크롤링하므로 시작일과 종료일이 같음

            # URL 생성
            encoded_text = urllib.parse.quote(text)  # 검색어를 url 인코딩
            url = f"https://search.naver.com/search.naver?where=news&query={encoded_text}&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds={y}.{m}.{start_d}&de={y}.{m}.{end_d}&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Ar%2Cp%3Afrom{y}{m}{start_d}to{y}{m}{end_d}&is_sug_officeid=0&office_category=0&service_area=0"

            # 페이지 열기
            driver.get(url)

            # 스크롤 1~2번 내리기
            last_height = driver.execute_script("return document.body.scrollHeight")
            for _ in range(2):  # 1~2번 스크롤 내리기
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(2)
                new_height = driver.execute_script("return document.body.scrollHeight")
                if new_height == last_height:
                    break
                last_height = new_height

            # 기사 제목, 날짜, 스크립트 크롤링
            titles = driver.find_elements(By.CSS_SELECTOR, ".news_tit")
            dates = driver.find_elements(By.CSS_SELECTOR, ".info_group > span")
            scripts = driver.find_elements(By.CSS_SELECTOR, ".dsc_txt_wrap")
            press = driver.find_elements(By.CSS_SELECTOR, ".info_group > a.press")

            # 상위 20개 기사만 저장
            for title, date, script, p in zip(titles[:20], dates[:20], scripts[:20], press[:20]):
                all_data.append({
                    "Title": title.text,
                    "Date": date.text,
                    "Press": p.text,
                    "Description": script.text
                })

# 데이터프레임 생성 및 저장
df1 = pd.DataFrame(all_data)
df1.to_csv(f"/Users/leesangwon/Downloads/{text}_{month}월_news_data.csv", index=False)

# 드라이버 종료
driver.quit()

# %%
import pandas as pd
aaa = pd.read_csv(f"/Users/leesangwon/Downloads/[속보]_['05']월_news_data.csv")
aaa
# Out:
#                                        Title         Date        Press  \
# 0          [속보]4월 수출 13.8% 증가…대미 수출 역대 최대 기록  2024.05.01.   경향신문언론사 선정
# 1               [속보]여야, 이태원특별법 합의…2일 본회의서 처리  2024.05.01.   국제신문언론사 선정
# 2           [속보] 與 사무총장에 배준영 내정…부총장에 서지영·김종혁  2024.05.01.   문화일보언론사 선정
# 3          [속보] 4월 수출 13.8%↑…7개월 연속 '수출 플러스'  2024.05.01.   한국경제언론사 선정
# 4       [속보] 대통령실 "이태원특별법 여야 합의 환영... 협치 성과"  2024.05.01.   한국일보언론사 선정
# ..                                       ...          ...          ...
# 615    [속보] 대법원, 김의철 전 KBS사장 해임처분 집행정지 신청 기각  2024.05.31.  미디어오늘언론사 선정
# 616     [속보] 尹정부, 원전 3기 더 짓는다…야당·환경단체 반발 불가피  2024.05.31.   국제신문언론사 선정
# 617     [속보] “바이든, ‘美 무기 사용’ 러시아 영토공격 일부 허용”  2024.05.31.   세계일보언론사 선정
# 618  [속보] 강남 오피스텔에서 모녀 살해한 뒤 도주...60대 용의자 체포  2024.05.31.    YTN언론사 선정
# 619          [속보]與 1호 법안은 '저출생‧민생' 초점 5대 패키지  2024.05.31.   노컷뉴스언론사 선정
#
#                                            Description
# 0    한국의 4월 수출이 지난해보다 13.8% 증가하면서 7개월 연속 ‘수출 플러스’ 행...
# 1    여야가 이태원 참사 특별법(10·29이태원참사 피해자 권리보장과 진상규명 및 재발방...
# 2    국민의힘은 1일 사무총장 직무대행인 배준영(사진) 의원을 사무총장으로 내정했다고 밝...
# 3    한국의 4월 수출이 지난해보다 13.8% 증가하면서 7개월 연속 '수출 플러스'를 ...
# 4    여야가 1일 '이태원 참사 진상규명 특별법'을 처리하기로 합의하자 대통령실은 즉각 ...
# ..                                                 ...
# 615  대법원이 지난 29일 김의철 전 KBS 사장이 윤석열 대통령을 상대로 제기한 해임처...
# 616  첨단산업 신규 투자 등에 따른 전력수요 급증에 대응하기 위해 2038년까지 최대 3...
# 617  기사 특정내용과 무관. 바흐무트=AP/뉴시스 조 바이든 행정부가 비밀리에 우크라이나...
# 618  강남에 있는 오피스텔에서 50대 여성과 그 딸에게 흉기를 휘둘러 숨지게 한 뒤 도주...
# 619  국민의힘은 31일 5대 분야 31개 법안을 1호 법안으로 선정, 22대 국회 최우선...
#
# [620 rows x 4 columns]

# %%
date_group = aaa.groupby('Date').size().reset_index(name='Count')
date_group.head(50)
# Out:
#            Date  Count
# 0         1면 1단      2
# 1   2024.05.01.     20
# 2   2024.05.02.     20
# 3   2024.05.03.     20
# 4   2024.05.04.     20
# 5   2024.05.05.     20
# 6   2024.05.06.     20
# 7   2024.05.07.     20
# 8   2024.05.08.     20
# 9   2024.05.09.     20
# 10  2024.05.10.     20
# 11  2024.05.11.     20
# 12  2024.05.12.     20
# 13  2024.05.13.     20
# 14  2024.05.14.     19
# 15  2024.05.15.     20
# 16  2024.05.16.     20
# 17  2024.05.17.     18
# 18  2024.05.18.     20
# 19  2024.05.19.     19
# 20  2024.05.20.     20
# 21  2024.05.21.     20
# 22  2024.05.22.     20
# 23  2024.05.23.     20
# 24  2024.05.24.     20
# 25  2024.05.25.     20
# 26  2024.05.26.     20
# 27  2024.05.27.     19
# 28  2024.05.28.     20
# 29  2024.05.29.     20
# 30  2024.05.30.     20
# 31  2024.05.31.     20
# 32      A12면 1단      1
# 33       A1면 1단      2

# %% [markdown]
# ### NLP

# %%
# !pip install konlpy
# !pip install wordcloud
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# Out:
# Requirement already satisfied: konlpy in /opt/anaconda3/lib/python3.12/site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from konlpy) (5.2.1)
# Requirement already satisfied: numpy>=1.6 in /opt/anaconda3/lib/python3.12/site-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from JPype1>=0.7.0->konlpy) (23.2)
# Requirement already satisfied: wordcloud in /opt/anaconda3/lib/python3.12/site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /opt/anaconda3/lib/python3.12/site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.12/site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: koreanize-matplotlib in /opt/anaconda3/lib/python3.12/site-packages (0.1.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (from koreanize-matplotlib) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)

# %%
import pandas as pd
file_path = "/Users/leesangwon/Documents/태블로대시보드용_금융데이터/속보_기간별_제목_4.csv"  # CSV 파일 경로
aaa = pd.read_csv(file_path)
aaa
# Out:
#      Term                                     Title  Date        Press
# 0       4              [속보] 부산 미군기지에서 불...대응 1단계 발령  3주 전    YTN언론사 선정
# 1       4          [속보] 尹 “우크라 살상무기 지원, 北 활동 따라 검토”  3주 전   매일경제언론사 선정
# 2       4                  [속보] 러 하원, 북러 조약 만장일치 비준  3주 전    뉴시스언론사 선정
# 3       4     [속보] 우크라 "북한군 2000명, 훈련 마치고 러 서부로 이동"  3주 전   중앙일보언론사 선정
# 4       4             [속보]3분기 韓경제 0.1% 성장…예상 밖 성장쇼크  3주 전  헤럴드경제언론사 선정
# ..    ...                                       ...   ...          ...
# 795     4          [속보] 9월 생산·소비 동반 감소…반도체 생산 2.6%↓  2주 전       강원도민일보
# 796     4         [속보] 삼성전자, 3분기 영업익 9.18조…10조 원 하회  2주 전   서울경제언론사 선정
# 797     4  [속보] 명태균 "김건희, '선생님, 윤상현한테 전화했습니다'라 말했다"  2주 전          더팩트
# 798     4     [속보] 민주, 윤석열-명태균 통화 녹음 공개…"尹 공천개입 입증"  2주 전    뉴스1언론사 선정
# 799     4   [속보] 토트넘, 리그컵 8강서 맨유와 격돌…'손흥민 우승 못 놓쳐!'  2주 전       엑스포츠뉴스
#
# [800 rows x 4 columns]

# %%
from konlpy.tag import Okt

def okt_tokenizer(text, return_nouns_only=True):
    """ 
    input: korean text
    output: tokens
    
    if return_nouns_only option is True, only nouns will be extracted.
    """
    okt = Okt()
    
    if return_nouns_only:
        tokens = okt.nouns(text)
    else:
        tokens = okt.morphs(text)
    
    # you can refer to the site below that lists Korean stopwords
    # https://www.ranks.nl/stopwords/korean
    stopwords = ['입니다', '은', '는', '이', '가', '이거', '저거', '그거', '여기', '이쪽', ]
    tokens = [n for n in tokens if n not in stopwords]
    return tokens

# %%
# Combine 'Title' and 'Description' columns into a list of words, split by commas
combined_list = []

# Iterate through each row in the dataframe
for _, row in aaa.iterrows():
    title_words = row['Title'].split(' ')
    #description_words = row['Description'].split(' ') if isinstance(row['Description'], str) else []
    combined_list.extend(title_words)

# The combined list of words
combined_list
# Out:
# ['[속보]',
#  '부산',
#  '미군기지에서',
#  '불...대응',
#  '1단계',
#  '발령',
#  '[속보]',
#  '尹',
#  '“우크라',
#  '살상무기',
#  '지원,',
#  '北',
#  '활동',
#  '따라',
#  '검토”',
#  '[속보]',
#  '러',
#  '하원,',
#  '북러',
#  '조약',
#  '만장일치',
#  '비준',
#  '[속보]',
#  '우크라',
#  '"북한군',
#  '2000명,',
#  '훈련',
#  '마치고',
#  '러',
#  '서부로',
#  '이동"',
#  '[속보]3분기',
#  '韓경제',
#  '0.1%',
#  '성장…예상',
#  '밖',
#  '성장쇼크',
#  '[속보]',
#  '검찰,',
#  "'공직선거법",
#  "위반'",
#  '김혜경',
#  '벌금',
#  '300만원',
#  '재구형',
#  '[속보]상급종합병원',
#  '구조전환에',
#  '세브란스·고대안암',
#  '등',
#  '8개',
#  '병원',
#  '선정',
#  '[속보]',
#  '검찰',
#  "'공직선거법",
#  "위반'",
#  '김혜경에',
#  '벌금',
#  '300만원',
#  '재구형',
#  '[속보]SK하이닉스',
#  '3분기',
#  '영업익',
#  '7조...반도체이익',
#  '삼성전자',
#  '넘어',
#  '[속보]',
#  'SK하이닉스',
#  '지붕',
#  '뚫었다...역대',
#  '최대',
#  '영업이익',
#  '7조300억',
#  '원으로',
#  '신...',
#  '[속보]',
#  '상급병원',
#  '구조전환',
#  '지원사업에',
#  '세브란스',
#  '등',
#  '8개',
#  '병원',
#  '1차',
#  '선정',
#  '[속보]SK하이닉스',
#  '3분기',
#  '영업익',
#  '7조...반도체이익',
#  '삼성전자',
#  '넘어',
#  '[속보]',
#  '美',
#  '“북한군',
#  '3천명',
#  '러서',
#  '훈련중…우크라전',
#  '투입땐',
#  '정당한',
#  '표적”',
#  '[속보]',
#  'SK하이닉스',
#  '지붕',
#  '뚫었다...역대',
#  '최대',
#  '영업이익',
#  '7조300억',
#  '원으로',
#  '신...',
#  '[속보]',
#  '부산',
#  '주한미군',
#  '55보급창서',
#  '큰',
#  '불…대응',
#  '2단계',
#  '[속보]',
#  '윤',
#  '대통령',
#  '"北',
#  '러시아',
#  '파병은',
#  '도발…좌시하지',
#  '않을',
#  '것"',
#  '[속보]',
#  '‘HBM',
#  '매출',
#  '330%',
#  '증가’',
#  'SK하이닉스,',
#  '3분기',
#  '영업익',
#  '7조300억원',
#  '‘...',
#  '[속보]',
#  '검찰,',
#  "'공직선거법",
#  "위반'",
#  '김혜경',
#  '3백만',
#  '원',
#  '구형',
#  '[속보]',
#  '이병노',
#  '담양군수',
#  '항소심도',
#  '당선무효형',
#  '[속보]',
#  '法',
#  '"공정위,',
#  '로톡',
#  '징계',
#  '변협',
#  '과징금',
#  '취소해야"',
#  '[속보]‘김',
#  '여사',
#  '비난',
#  '전단’',
#  '담은',
#  '오물풍선',
#  '北',
#  '살포…대통령실',
#  '청사에...',
#  '[속보]',
#  '3분기',
#  '실질GDP',
#  '성장률',
#  '0.1%에',
#  '그쳐···수출은',
#  '0.4%',
#  '감소',
#  '[속보]',
#  '검찰',
#  "'공직선거법위반'",
#  '김혜경',
#  '벌금',
#  '300만원',
#  '구형',
#  '[속보]한동훈',
#  '“당',
#  '대표,',
#  '원내든',
#  '원외든',
#  '당',
#  '전체업무',
#  '총괄…특별감찰관...',
#  '[속보]',
#  '현대차',
#  '3분기',
#  '매출',
#  '43조',
#  '육박',
#  '‘역대',
#  '최대’…영업익은',
#  '6.5%',
#  '감소',
#  '[속보]',
#  '윤',
#  '대통령',
#  '국정지지율',
#  '22%…취임',
#  '후',
#  '최저치',
#  '기록',
#  '[속보]',
#  '이병노',
#  '담양군수',
#  '항소심도',
#  '당선무효형',
#  '[속보]용산',
#  '대통령실에',
#  '北',
#  '쓰레기풍선',
#  '낙하,',
#  '당국',
#  '신속',
#  '처리',
#  '[속보]3분기',
#  'GDP',
#  '전기比',
#  '0.1%↑…간신히',
#  '증가',
#  '전환',
#  '[속보]',
#  '尹',
#  '"北',
#  '러시아',
#  '파병,',
#  '좌시',
#  '않을',
#  '것…단계별로',
#  '조치하겠다"',
#  '[속보]',
#  '부산',
#  '미군기지에서',
#  '화재',
#  '발생...대응',
#  '1단계',
#  '발령',
#  '[속보]',
#  '3분기',
#  '경제성장률',
#  '0.1%…"민간소비·건설투자',
#  '부진"',
#  '[속보]',
#  '3분기',
#  '경제성장률',
#  '0.1%',
#  '성장…소폭',
#  '상승',
#  '전환',
#  '[속보]',
#  '우크라',
#  '군소식통',
#  '"북한군',
#  '2천명',
#  '러',
#  '서부로',
#  '이동중"<교도>',
#  '[속보]',
#  '오재원,',
#  '‘또',
#  '마약’',
#  '혐의로',
#  '징역4개월',
#  '집유2년',
#  '추가',
#  '[속보]',
#  '러',
#  '하원,',
#  '북러',
#  "'포괄적",
#  '전략적',
#  '동반자',
#  '관계',
#  "조약'",
#  '비준',
#  '[속보]',
#  '헌법재판소장',
#  '권한대행에',
#  '문형배',
#  '재판관',
#  '[속보]',
#  '尹,',
#  '우크라',
#  '무기',
#  '지원에',
#  '"북한군',
#  '활동에',
#  '따라',
#  '유연하게',
#  '검토"',
#  '[속보]SK이노',
#  '계열사',
#  '수장',
#  '3명',
#  '교체…SK지오센트릭',
#  '대표에',
#  '최안섭',
#  '사장',
#  '[속보]',
#  '윤',
#  '대통령',
#  '"한-폴란드,',
#  '우크라이나',
#  '지원',
#  '확대해',
#  '나갈',
#  '것"',
#  '[속보]',
#  '"북한군',
#  '2000명',
#  '러시아',
#  '서부로',
#  '이동',
#  '중"',
#  '[속보]',
#  '윤',
#  '대통령',
#  '“우크라',
#  '살상무기',
#  '지원,',
#  '北',
#  '활동',
#  '따라',
#  '검토”',
#  '[속보]KB국민은행,',
#  '3분기',
#  '순이익',
#  '1조1120억원…전년比',
#  '11.5%↑',
#  '[속보]',
#  '윤',
#  '대통령',
#  '"北',
#  '러시아',
#  '파병은',
#  '도발…러북',
#  '불법',
#  '군사협력',
#  '좌시',
#  '안...',
#  '[속보]',
#  '검찰,',
#  "'선거법",
#  "위반'",
#  '김혜경에',
#  '벌금',
#  '300만원',
#  '재구형',
#  '[속보]',
#  '3분기',
#  '경제',
#  '성장률',
#  '0.1%...',
#  '"수출',
#  '증가세',
#  '예상보다',
#  '둔화"',
#  '[속보]검찰,',
#  "'선거법",
#  "위반'",
#  '김혜경에',
#  '벌금',
#  '300만원',
#  '재구형',
#  '[속보]尹',
#  '"폴란드와',
#  '방산',
#  '협력…연내',
#  'K2',
#  '전차',
#  '2차',
#  '이행계약"',
#  '[속보]',
#  '“북한의',
#  '러시아',
#  '파병,',
#  '전',
#  '세계',
#  '안보',
#  '위협하는',
#  '도발”',
#  '[속보]',
#  '3분기',
#  'GDP',
#  '0.1%',
#  '증가…예상치',
#  '하회',
#  '[속보]尹',
#  '“폴란드와',
#  '방산',
#  '협력…연내',
#  'K2',
#  '전차',
#  '2차',
#  '이행계약”',
#  '[속보]',
#  '부산',
#  '주한미군',
#  '55보급창',
#  '화재…소방',
#  '대응',
#  '1단계',
#  '[속보]',
#  '尹대통령',
#  '"北',
#  '러시아',
#  '파병은',
#  '도발…좌시하지',
#  '않을',
#  '것"',
#  '[속보]끝없이',
#  '오르는',
#  '美국채금리…나스닥',
#  '1.6%↓',
#  '[속보]SK하이닉스',
#  '3분기',
#  '영업익',
#  '7조300억',
#  '[속보]',
#  '여성에게',
#  '2주치',
#  '수면제',
#  '몰래',
#  '먹여',
#  '살해한',
#  '70대',
#  '男,',
#  '징역',
#  '25년',
#  '[속보]',
#  '북한',
#  '쓰레기',
#  '풍선',
#  '낙하물',
#  '대통령실',
#  '청사에',
#  '떨어져',
#  '[속보]현대차',
#  '3분기',
#  '영업이익',
#  '3조5809억원…작년',
#  '대비',
#  '6.5%↓',
#  '[속보]',
#  'SK하이닉스,',
#  '3분기',
#  '영업익',
#  '7조299억...흑자전환',
#  '[속보]',
#  'LG전자,',
#  '3분기',
#  '영업익',
#  '7519억…전년비',
#  '20.9%↓',
#  '[속보]',
#  '한동훈',
#  '"당대표는',
#  '원내·원외',
#  '총괄…특별감찰관',
#  '추천',
#  '진행할',
#  '것...',
#  '[속보]',
#  '법사위,',
#  '야',
#  '주도',
#  '감사원장·사무총장',
#  '고발',
#  '의결…"자료제출',
#  '요구...',
#  '[속보]',
#  '美백악관',
#  '"북한군,',
#  '러서',
#  '훈련',
#  '마치고',
#  '우크라군과',
#  '싸울',
#  '가능성"',
#  '[속보]',
#  '한동훈',
#  '"당',
#  '대표,',
#  '원내든',
#  '원외든',
#  '당',
#  '전체',
#  '총괄업무',
#  '수행"',
#  '[속보]',
#  '한동훈',
#  '"대표,',
#  '당',
#  '업무',
#  '총괄',
#  '수행…특별감찰관',
#  '추천하자"',
#  '[속보]',
#  'SK하이닉스',
#  '3분기',
#  '영업이익',
#  '7조300억원…흑자',
#  '전환',
#  '[속보]현대차,',
#  '3분기',
#  '영업익',
#  '3조5809억원…전년비',
#  '6.5%',
#  '감소',
#  '[속보]尹',
#  '"K2전차',
#  '2차',
#  '이행계약',
#  '등',
#  '한-폴란드',
#  '방산협력',
#  '적극',
#  '지원"',
#  '[속보]',
#  '3분기',
#  '실질',
#  'GDP',
#  '전분기',
#  '대비',
#  '0.1%',
#  '↑',
#  '[속보]',
#  'IMF',
#  '"올해',
#  '韓',
#  '1인당',
#  '소득,',
#  '日·대만',
#  '여유있게',
#  '앞설',
#  '것…4만달러',
#  '...',
#  '[속보]',
#  '대통령실',
#  '“북한',
#  '쓰레기풍선',
#  '용산청사',
#  '공중서',
#  '터져…오염성',
#  '없어...',
#  '[속보]',
#  '현대자동차',
#  '3분기',
#  '영업이익',
#  '3.5조원…작년',
#  '대비',
#  '6.5%↓',
#  '[속보]',
#  '3분기',
#  '한국',
#  '경제',
#  '성장률',
#  '0.1%…"수출',
#  '증가세',
#  '둔화"',
#  '2024년',
#  '3/4분기',
#  '실질',
#  '국내총생산(속보)',
#  '설명회',
#  '[속보]윤',
#  '"한-폴란드',
#  '첨단기술',
#  '전략',
#  '파트너십',
#  '구축할',
#  '것"',
#  '[속보]한동훈',
#  '"대통령실',
#  '직속',
#  '반도체경쟁력',
#  '강화위',
#  '설치',
#  '제안"',
#  '[속보]',
#  '북한',
#  '쓰레기',
#  '풍선',
#  '낙하물,',
#  '대통령실',
#  '청사에',
#  '낙하',
#  '[속보]KB금융,',
#  '3분기',
#  '순이익',
#  '1조6140원…전년比',
#  '17.9%↑',
#  '[속보]',
#  '합참',
#  '"北,',
#  '대남',
#  '쓰레기',
#  '풍선',
#  '부양"',
#  '올해',
#  '30번째',
#  '[속보][뉴욕증시]',
#  '나스닥도',
#  '하락',
#  '합류...엔비디아,',
#  '2.8%',
#  '급락',
#  '[속보]',
#  '보잉',
#  '노조,',
#  '계약',
#  '거부',
#  '파업',
#  '연장',
#  '[속보]',
#  '미',
#  '백악관',
#  '"북한군',
#  '3천',
#  '명',
#  '러',
#  '동부로',
#  '이동...전쟁',
#  '투입',
#  '우려"',
#  '[속보]',
#  'SK하이닉스',
#  '3분기',
#  '매출',
#  '17조5731억',
#  '원…분기',
#  '사상',
#  '최대',
#  '[속보]복지차관',
#  '"의료개혁,',
#  '의료영리화',
#  '추진',
#  '전혀',
#  '사실',
#  '아냐"',
#  '[속보]테슬라',
#  '3분기',
#  '실적',
#  '예상치',
#  '상회…시간외서',
#  '9%',
#  '넘게',
#  '폭등',
#  '[속보]',
#  '테슬라',
#  '시간외거래서',
#  '12%까지',
#  '폭등',
#  '[속보]',
#  '“우크라이나',
#  '평화',
#  '회복·재건',
#  '위한',
#  '공동',
#  '노력',
#  '강화”',
#  '[속보]',
#  '윤',
#  '대통령',
#  '"북·러',
#  '군사협력',
#  '진전',
#  '따라',
#  '단계별로',
#  '조치"',
#  '[속보]',
#  '“원자력',
#  '등',
#  '무탄소',
#  '에너지',
#  '확대',
#  '방안',
#  '함께',
#  '모색”',
#  '[속보]현대차,',
#  '3분기',
#  '주당',
#  '2000원',
#  '배당',
#  '[속보]',
#  '현대차,',
#  '3분기',
#  '매출',
#  '42조9283억…영업익',
#  '3조5809억',
#  '[속보]',
#  '윤',
#  '"한-폴란드,',
#  '북',
#  '도발·러시아',
#  '불법',
#  '군사협력',
#  '규탄"',
#  '[속보]',
#  '정부',
#  '"총액인건비',
#  '규제',
#  '안',
#  '받는',
#  '필수의료',
#  '유지',
#  '특별수당',
#  '신설"',
#  '[속보]',
#  'LG전자',
#  '3분기',
#  '영업이익',
#  '7519억원…전년比',
#  '20.9%↓',
#  '[속보]',
#  'SK하이닉스',
#  '3분기',
#  '영업이익',
#  '7조300억원...흑자',
#  '전환',
#  '[속보]윤',
#  '"北',
#  '러',
#  '파병,',
#  '좌시',
#  '안해…폴란드와',
#  '굳건히',
#  '연대"',
#  '[속보]尹',
#  '“폴란드와',
#  '방산·에너지·첨단산업',
#  '협력',
#  '심화”',
#  '[속보]',
#  '윤',
#  '"북,',
#  '러시아',
#  '파병',
#  '세계',
#  '안보',
#  '위협…결코',
#  '좌시하지',
#  '않아"',
#  '[속보]현대차',
#  '3분기',
#  '영업이익',
#  '3조',
#  '5809억…6.5%↓',
#  '[속보]',
#  '테슬라',
#  '실적',
#  '예상',
#  '상회,',
#  '시간외서',
#  '8%',
#  '급등',
#  '[속보]북한,',
#  '러시아',
#  '파병',
#  '관련',
#  '첫',
#  '입장',
#  '“국제법적',
#  '규범에',
#  '부합한',
#  '행동...',
#  '[속보]',
#  '배우',
#  '김수미',
#  '별세..향년',
#  '75세',
#  '[속보]',
#  '우크라',
#  '"북한군',
#  '27∼28일',
#  '전투지역',
#  '투입',
#  '예상"',
#  '[속보]',
#  '배우',
#  '김수미',
#  '별세…향년',
#  '75세',
#  '[속보]',
#  '크렘린궁,',
#  '내년',
#  '김정은',
#  '방러',
#  '가능성',
#  '시사',
#  '[속보]윤',
#  '대통령,',
#  '공수처',
#  '검사',
#  '4명',
#  '연임안',
#  '재가',
#  '[속보]',
#  '北,',
#  '러',
#  '파병',
#  '사실상',
#  '시인…"그런',
#  '일',
#  '있다면',
#  '국제규범',
#  '부합"',
#  '[속보]네덜란드',
#  '“러,',
#  '북한군',
#  '최소',
#  '1500명',
#  '배치',
#  '중”',
#  '[속보]',
#  '현대차',
#  '이어',
#  '기아도…분기',
#  '실적',
#  '역대',
#  '최대',
#  '올렸다',
#  '[속보]',
#  '대통령실',
#  '"지지율',
#  '하락,',
#  '국민',
#  '목소리',
#  '귀기울이겠다"',
#  '[속보]',
#  "'한동훈",
#  "명예훼손'",
#  '황희석',
#  '벌금',
#  '500만원',
#  '확정',
#  '[속보]',
#  '배우',
#  '김수미',
#  '별세…향년',
#  '75세',
#  '[속보]체포된',
#  '40대女',
#  '수배자,',
#  '순찰차',
#  '뒷자리서',
#  '살충제',
#  '음료',
#  '마셔',
#  '병원행',
#  '[속보]한동훈',
#  '“쇄신',
#  '방해,',
#  '자해적',
#  '이간질로',
#  '알량한',
#  '이득보려는',
#  '사람',
#  '있...',
#  '[속보]',
#  '푸틴',
#  '“북한군,',
#  '러시아',
#  '파병',
#  '우리가',
#  '알아서',
#  '할',
#  '일”...사실상',
#  '인...',
#  '[속보]대통령실,',
#  '“신',
#  '북풍몰이”',
#  '야당',
#  '비판에',
#  '“북한',
#  '파병',
#  '규탄이',
#  '먼저...',
#  '[속보]',
#  '푸틴,',
#  '‘북한군',
#  '파병’',
#  '부인',
#  '않고',
#  '“우리가',
#  '알아서',
#  '할',
#  '일”',
#  '[속보]',
#  '대통령실',
#  '"지지율',
#  '하락,',
#  '국민',
#  '목소리',
#  '귀기울이겠다"',
#  '[속보]',
#  '네덜란드',
#  '"러,',
#  '북한군',
#  '최소',
#  '1500명',
#  '배치중"',
#  '[속보]',
#  '우크라',
#  '"북한군',
#  '27∼28일',
#  '전투지역',
#  '투입',
#  '예상"',
#  '[속보]',
#  '"술',
#  '취해',
#  '기억',
#  '없다"',
#  '지인',
#  '살해',
#  '50대',
#  '징역',
#  '20년',
#  '중형',
#  '선고',
#  '[속보]',
#  '푸틴',
#  '"때되면',
#  '북러',
#  '조약상',
#  '군사상호지원',
#  '적용',
#  '결정"',
#  '[속보]',
#  '尹',
#  '대통령,',
#  "'채상병",
#  '수사',
#  "담당'",
#  '공수처',
#  '검사',
#  '4명',
#  '연임',
#  '재가',
#  '[속보]',
#  '북,',
#  '러',
#  '파병에',
#  '첫',
#  '입장',
#  '"그런',
#  '일',
#  '있다면',
#  '국제법적',
#  '규범에',
#  '부합"',
#  '[속보]',
#  '우크라',
#  '“북한군',
#  '23일',
#  '러',
#  '남서부',
#  '쿠르스크',
#  '배치돼”',
#  '[속보]',
#  '푸틴',
#  '"상호',
#  '군사지원,',
#  '오직',
#  '북·러',
#  '양국의',
#  '문제"',
#  '[속보]',
#  '김수미',
#  '별세,',
#  '건강',
#  '악화',
#  '우려',
#  '한',
#  '달만에',
#  '[속보]',
#  '대통령실',
#  '"尹',
#  '지지율',
#  '하락',
#  '엄중히',
#  '인식..개혁',
#  '더',
#  '힘쓸',
#  '것"',
#  '[속보]',
#  '탤런트',
#  '김수미',
#  '별세…향년',
#  '75세',
#  '[속보]대통령실,',
#  '한기호',
#  "'북괴군",
#  "폭격'",
#  '문자에',
#  ...]

# %%
result = ' '.join(combined_list)  # 공백으로 결합
print(result)
# Out:
# [속보] 부산 미군기지에서 불...대응 1단계 발령 [속보] 尹 “우크라 살상무기 지원, 北 활동 따라 검토” [속보] 러 하원, 북러 조약 만장일치 비준 [속보] 우크라 "북한군 2000명, 훈련 마치고 러 서부로 이동" [속보]3분기 韓경제 0.1% 성장…예상 밖 성장쇼크 [속보] 검찰, '공직선거법 위반' 김혜경 벌금 300만원 재구형 [속보]상급종합병원 구조전환에 세브란스·고대안암
', '률', '수출', '증가', '세', '둔화', '실질', '국내총생산', '속보', '설명', '회', '속보', '윤', '폴란드', '첨단', '기술', '전략', '파트너', '구축', '것', '속보', '한동훈', '대통령실', '직속', '반도체', '경쟁력', '강화', '위', '설치', '제안', '속보', '북한', '쓰레기', '풍선', '낙하', '물', '대통령실', '청사', '낙하', '속보', '금융', '순이익', '년', '속보', '합참', '대남', '쓰레기', '풍선', '부양', '올해', '속보', '뉴욕증시', '나스닥', '하락', '합류', '엔비디아', '급락', '속보', '보잉', '노조', '계약', '거부', '파업', '연장', '속보', '백악관', '북한', '명', '동부', '이동', '전쟁', '투입', '우려', '속보', '하이닉스', '매출', '원', '분기', '사상', '최대', '속보', '복지', '차관', '의료', '개혁', '의료', '영리', '추진', '전혀', '사실', '속보', '테슬라', '실적', '상치', '상회', '시간', '외', '폭등', '속보 ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 예시 리스트 (단어들이 들어 있는 리스트)

# 리스트를 문자열로 변환 (워드클라우드를 만들기 위해)
text = ' '.join(nouns)

# CountVectorizer를 사용하여 텍스트 벡터화
vectorizer = CountVectorizer(stop_words=None)  # stop_words=None을 사용하여 불용어 제외
X = vectorizer.fit_transform([text])

# 벡터화된 단어와 그 빈도수 출력
word_freq = dict(zip(vectorizer.get_feature_names_out(), X.toarray().flatten()))


word_freq_df = pd.DataFrame(word_freq.items(), columns=["Word", "Frequency"])


word_freq_df.to_csv("/Users/leesangwon/Documents/태블로대시보드용_금융데이터/4기간.csv", index=False, encoding="utf-8")

# %%
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
import pandas as pd

# 데이터 준비
titles = data['Title'].dropna()
result = ' '.join(titles)  # 'Title' 컬럼의 내용을 하나의 문자열로 결합

# Okt를 이용한 명사 추출
okt = Okt()
nouns = okt.nouns(result)  # 명사만 추출

# 단어 벡터화
text = ' '.join(nouns)  # 명사 리스트를 문자열로 변환
vectorizer = CountVectorizer()
X = vectorizer.fit_transform([text])

# 단어와 빈도수 딕셔너리 생성
word_freq = dict(zip(vectorizer.get_feature_names_out(), X.toarray().flatten()))

# 워드 빈도 CSV 저장
word_freq_df = pd.DataFrame(word_freq.items(), columns=["Word", "Frequency"])
file_path = "/mnt/data/1기간.csv"
word_freq_df.to_csv(file_path, index=False, encoding="utf-8")

# 저장된 경로 반환
file_path

# %%
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 예시 리스트 (단어들이 들어 있는 리스트)

# 리스트를 문자열로 변환 (워드클라우드를 만들기 위해)
text = ' '.join(nouns)

# CountVectorizer를 사용하여 텍스트 벡터화
vectorizer = CountVectorizer(stop_words=None)  # stop_words=None을 사용하여 불용어 제외
X = vectorizer.fit_transform([text])

# 벡터화된 단어와 그 빈도수 출력
word_freq = dict(zip(vectorizer.get_feature_names_out(), X.toarray().flatten()))
print(word_freq)

# 워드클라우드 생성
wordcloud = WordCloud(width=800, height=400).generate_from_frequencies(word_freq)

# 워드클라우드 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# CSV 파일 읽기
file_path = "/Users/leesangwon/Documents/태블로대시보드용_금융데이터/속보_기간별_제목_4.csv"  # CSV 파일 경로
df = pd.read_csv(file_path)

# 텍스트 열 지정 (예: 'text' 열에서 단어 추출)
text_column = "Title"  # CSV 파일 내 텍스트 열 이름
text = " ".join(df[text_column].astype(str))

# CountVectorizer를 사용하여 텍스트 벡터화
vectorizer = CountVectorizer(stop_words=None)  # stop_words=None을 사용하여 불용어 제외
X = vectorizer.fit_transform([text])

# 벡터화된 단어와 그 빈도수 출력
word_freq = dict(zip(vectorizer.get_feature_names_out(), X.toarray().flatten()))
word_freq




# # 데이터 확인
# data

# data.to_csv("/Users/leesangwon/Documents/태블로대시보드용_금융데이터/4기간.csv", index=False, encoding="utf-8")
# Out:
# {'05': 1,
#  '07p': 1,
#  '09': 1,
#  '10': 3,
#  '1000': 3,
#  '100여개': 1,
#  '100일': 3,
#  '104': 1,
#  '10년': 5,
#  '10대': 1,
#  '10월': 3,
#  '10일': 3,
#  '10조': 1,
#  '11': 1,
#  '110회': 1,
#  '1143회': 1,
#  '11월': 4,
#  '12': 2,
#  '12번째': 3,
#  '12월': 1,
#  '13': 4,
#  '132': 1,
#  '1390원': 3,
#  '13억원': 1,
#  '14': 1,
#  '1400원대': 1,
#  '140여곳': 1,
#  '1450원도': 3,
#  '148': 1,
#  '14건': 1,
#  '14만달러설까지': 1,
#  '14조원': 1,
#  '1500명': 2,
#  '150억': 1,
#  '155': 1,
#  '155mm': 1,
#  '15개': 1,
#  '15년': 3,
#  '16': 2,
#  '16p': 1,
#  '17': 2,
#  '174': 1,
#  '17조5731억': 1,
#  '18': 3,
#  '1834억': 1,
#  '18p': 2,
#  '18조': 1,
#  '19': 1,
#  '191': 1,
#  '1공장': 1,
#  '1단계': 4,
#  '1만': 1,
#  '1만1000명': 2,
#  '1만1천명': 1,
#  '1만900여명': 1,
#  '1만명': 2,
#  '1명': 1,
#  '1발': 2,
#  '1승': 1,
#  '1심': 2,
#  '1심서': 1,
#  '1심에서': 1,
#  '1억원': 1,
#  '1월': 1,
#  '1월2일': 2,
#  '1인당': 2,
#  '1조1120억원': 1,
#  '1조1566억원': 1,
#  '1조2386억': 2,
#  '1조3천808억': 1,
#  '1조493억': 1,
#  '1조6140원': 1,
#  '1차': 1,
#  '1천명': 1,
#  '1패로': 1,
#  '1회': 1,
#  '1회초': 1,
#  '20': 7,
#  '2000명': 2,
#  '2000원': 1,
#  '2009년': 2,
#  '201일': 1,
#  '2024': 1,
#  '2024년': 1,
#  '2025년': 1,
#  '20년': 3,
#  '20대': 1,
#  '22': 4,
#  '2249억': 1,
#  '23억원': 1,
#  '23일': 2,
#  '24': 5,
#  '24p': 1,
#  '24도': 1,
#  '24명': 1,
#  '24일': 1,
#  '254석': 1,
#  '2550': 4,
#  '2583': 1,
#  '2588': 1,
#  '2597': 1,
#  '25년': 1,
#  '25주기': 1,
#  '2600선을': 1,
#  '2612': 1,
#  '2680': 4,
#  '26일': 3,
#  '26조5198억': 1,
#  '26조5198억원': 1,
#  '26조5199억': 1,
#  '27': 4,
#  '277': 1,
#  '27일까': 1,
#  '27일부터': 1,
#  '28': 1,
#  '28명': 1,
#  '28일': 4,
#  '28일까지': 1,
#  '29': 1,
#  '2공개': 1,
#  '2년': 6,
#  '2단계': 1,
#  '2명': 1,
#  '2심': 1,
#  '2심서': 1,
#  '2심서도': 1,
#  '2일': 1,
#  '2조': 1,
#  '2조3151억': 1,
#  '2조8812억': 1,
#  '2조8813억원': 2,
#  '2조원': 1,
#  '2주기': 1,
#  '2주치': 1,
#  '2차': 5,
#  '2천명': 1,
#  '2패': 1,
#  '2회': 1,
#  '30': 1,
#  '3000명': 2,
#  '300만원': 5,
#  '30명당': 1,
#  '30번째': 1,
#  '30조': 3,
#  '31': 1,
#  '31일': 2,
#  '32': 2,
#  '33': 1,
#  '330': 1,
#  '34p': 1,
#  '36': 2,
#  '36주차': 1,
#  '373만2650주': 1,
#  '373만주': 1,
#  '38': 2,
#  '3q': 5,
#  '3개': 1,
#  '3국': 1,
#  '3만원석': 1,
#  '3명': 2,
#  '3방': 1,
#  '3백만': 1,
#  '3번방': 2,
#  '3분기': 59,
#  '3승': 1,
#  '3월': 1,
#  '3조': 2,
#  '3조5809억': 1,
#  '3조5809억원': 2,
#  '3조9000억원': 1,
#  '3주': 3,
#  '3차': 1,
#  '3차전': 2,
#  '3차전서': 1,
#  '3천': 1,
#  '3천명': 2,
#  '3호골': 1,
#  '4000명': 1,
#  '40대女': 1,
#  '41': 3,
#  '41p': 1,
#  '42': 2,
#  '42조9283억': 1,
#  '43': 1,
#  '43조': 1,
#  '44': 1,
#  '4483억': 1,
#  '4483억원': 1,
#  '45': 1,
#  '450원': 1,
#  '457': 1,
#  '465석': 1,
#  '46p': 1,
#  '46명': 1,
#  '46표': 1,
#  '4772억': 1,
#  '48': 2,
#  '4984억': 1,
#  '4984억원': 1,
#  '4개월만': 1,
#  '4개월여만에': 3,
#  '4거래일': 1,
#  '4대': 7,
#  '4대개혁': 1,
#  '4만달러': 1,
#  '4명': 3,
#  '4방': 1,
#  '4방으로': 1,
#  '4번째': 1,
#  '4분기': 2,
#  '4일': 1,
#  '4차전': 1,
#  '4차전서': 1,
#  '5000만': 4,
#  '5000명': 1,
#  '500만원': 1,
#  '50대': 1,
#  '515억': 1,
#  '51명': 1,
#  '53': 1,
#  '54명': 1,
#  '55명': 1,
#  '55보급창': 2,
#  '55보급창서': 1,
#  '56': 2,
#  '5809억': 1,
#  '5년': 2,
#  '5대': 1,
#  '5명': 3,
#  '5일': 3,
#  '5일차': 1,
#  '5조': 2,
#  '5조원': 2,
#  '5차전': 1,
#  '5회': 1,
#  '60': 1,
#  '600선': 1,
#  '60대': 1,
#  '60만명': 1,
#  '61': 2,
#  '64': 1,
#  '68000달러': 1,
#  '6개': 1,
#  '6개월여': 1,
#  '6개월째': 1,
#  '6경기': 1,
#  '6만': 1,
#  '6만6000달러': 1,
#  '6만8000달러': 1,
#  '6만원': 1,
#  '6주': 1,
#  '6회말': 1,
#  '70': 1,
#  '7000': 1,
#  '70대': 2,
#  '727': 1,
#  '729': 1,
#  '72분': 1,
#  '73': 1,
#  '739': 1,
#  '740': 1,
#  '75': 2,
#  '7519억': 1,
#  '7519억원': 1,
#  '757양도마을': 1,
#  '75세': 9,
#  '75세로': 1,
#  '76': 2,
#  '77': 1,
#  '78분': 1,
#  '79조897억': 1,
#  '7개월만': 1,
#  '7년': 3,
#  '7년만에': 1,
#  '7년만의': 1,
#  '7대': 1,
#  '7만1000달러도': 1,
#  '7만2000달러': 1,
#  '7만2천달러선': 1,
#  '7만달러': 1,
#  '7만달러선': 3,
#  '7명': 1,
#  '7법': 1,
#  '7조': 2,
#  '7조299억': 1,
#  '7조300억': 3,
#  '7조300억원': 3,
#  '7차': 1,
#  '7천3달러선': 1,
#  '80': 1,
#  '800달러': 1,
#  '800명에': 1,
#  '810억': 1,
#  '84': 1,
#  '8400여명': 1,
#  '85': 3,
#  '8600억': 1,
#  '86분': 1,
#  '8813억': 1,
#  '8강서': 1,
#  '8개': 2,
#  '8번째': 1,
#  '8일': 1,
#  '8중': 1,
#  '9036억원': 1,
#  '9040억': 1,
#  '9086억원': 1,
#  '96': 1,
#  '98': 1,
#  '99표': 1,
#  '9월': 10,
#  '9조': 2,
#  '9조1834억': 1,
#  '9조1834억원': 1,
#  '9조2000억원': 1,
#  '9천5백': 1,
#  'acb뉴스': 1,
#  'afc': 1,
#  'afp': 1,
#  'ai': 6,
#  'ann': 1,
#  'asf울타리': 1,
#  'btc': 2,
#  'cctv': 1,
#  'cnn': 1,
#  'ds단석': 1,
#  'ebn': 3,
#  'edf': 1,
#  'espn': 1,
#  'eu': 4,
#  'eu위원장': 1,
#  'fomc': 1,
#  'gdp': 10,
#  'gps': 1,
#  'hbm': 3,
#  'icbm': 12,
#  'icbm급': 2,
#  'icbm은': 1,
#  'idf': 1,
#  'imf': 1,
#  'ing': 1,
#  'irbm': 1,
#  'k2': 2,
#  'k2전차': 1,
#  'kb국민은행': 1,
#  'kb금융': 1,
#  'kia': 12,
#  'ks': 2,
#  'ks3': 1,
#  'ks4': 1,
#  'k대대': 1,
#  'k칩스법': 1,
#  'lg家': 2,
#  'lg엔솔': 2,
#  'lg전자': 2,
#  'lg화학': 2,
#  'm7': 6,
#  'mbk': 4,
#  'mlb': 1,
#  'mvp': 2,
#  'nhk': 8,
#  'nh농협금융': 1,
#  'nsc': 4,
#  'n번방': 3,
#  'n번방은': 1,
#  'out': 2,
#  'p500': 1,
#  'pce': 3,
#  'plus': 1,
#  'psg': 2,
#  'scm': 1,
#  'sk이노': 1,
#  'sk지오센트릭': 1,
#  'sk하이닉스': 10,
#  'sm': 4,
#  'tel': 1,
#  'tv토론': 1,
#  'v12': 4,
#  'v12까지': 1,
#  'vi': 12,
#  'ws': 1,
#  'ws2': 1,
#  'ws4': 1,
#  'wti': 1,
#  'yg': 1,
#  '北icbm': 1,
#  '北김영복': 1,
#  '北미사일': 1,
#  '北외무상과': 1,
#  '北파병': 5,
#  '北파병에': 1,
#  '對中': 3,
#  '對이란': 4,
#  '尹당선인': 1,
#  '尹대통령': 6,
#  '尹정부': 1,
#  '尹지지율': 1,
#  '新북풍': 1,
#  '日銀총재': 1,
#  '日방위성': 3,
#  '日언론': 1,
#  '日여당': 1,
#  '日중의원': 3,
#  '日지지통신': 1,
#  '美국채금리': 1,
#  '美대선': 2,
#  '美백악관': 1,
#  '美법무부': 1,
#  '美언론': 1,
#  '與배제': 1,
#  '與추천': 1,
#  '韓美日': 1,
#  '韓경제': 1,
#  '韓과': 1,
#  '韓원전': 1,
#  '가계부채는': 1,
#  '가금농장': 1,
#  '가까스로': 3,
#  '가까운': 1,
#  '가능': 7,
#  '가능성': 16,
#  '가능성도': 5,
#  '가능성에': 2,
#  '가독성': 1,
#  '가라': 1,
#  '가상화폐': 2,
#  '가시적': 2,
#  '가시화': 1,
#  '가을': 1,
#  '가자': 1,
#  '가장': 4,
#  '가정': 1,
#  '가족': 1,
#  '가족돌봄청년': 1,
#  '가족에': 1,
#  '가처분': 5,
#  '가치': 1,
#  '가할': 1,
#  '각오로': 1,
#  '각하': 4,
#  '간과': 1,
#  '간다': 1,
#  '간신히': 1,
#  '간주': 1,
#  '간첩': 1,
#  '간첩죄': 2,
#  '감독': 2,
#  '감사원장': 1,
#  '감소': 5,
#  '감시': 1,
#  '감지': 2,
#  '감행': 2,
#  '강구': 2,
#  '강력': 1,
#  '강력규탄': 1,
#  '강력히': 1,
#  '강세장': 1,
#  '강영권': 1,
#  '강원': 3,
#  '강제집행': 1,
#  '강한': 2,
#  '강행': 1,
#  '강혜경': 1,
#  '강화': 3,
#  '강화군': 1,
#  '강화위': 1,
#  '개발': 1,
#  '개방': 1,
#  '개선': 1,
#  '개선안': 2,
#  '개연성': 2,
#  '개인': 2,
#  '개인소비지출': 1,
#  '개인적인': 1,
#  '개입': 2,
#  '개장': 4,
#  '개정': 1,
#  '개정안': 2,
#  '개최': 5,
#  '개혁': 8,
#  '개혁이': 1,
#  '개혁추진': 1,
#  '갤럽': 1,
#  '거듭나야': 1,
#  '거론': 1,
#  '거부': 1,
#  '거부했었다': 1,
#  '거주': 1,
#  '거짓': 1,
#  '거짓말이': 1,
#  '건강': 1,
#  '건물': 1,
#  '건설': 2,
#  '건설투자': 1,
#  '건의': 1,
#  '걸친': 1,
#  '검사': 2,
#  '검찰': 11,
#  '검토': 14,
#  '검토한': 2,
#  '검토한다는': 1,
#  '검토할': 2,
#  '검토해볼': 1,
#  '것과': 1,
#  '것뿐': 1,
#  '것은': 2,
#  '것이': 1,
#  '겨냥': 3,
#  '격돌': 2,
#  '격리': 1,
#  '격상': 2,
#  '격전지': 1,
#  '격퇴': 1,
#  '결속용': 1,
#  '결장': 1,
#  '결장한다': 1,
#  '결정': 4,
#  '결코': 1,
#  '결행': 1,
#  '경계': 9,
#  '경고': 1,
#  '경관': 1,
#  '경기': 12,
#  '경기일정은': 1,
#  '경기종합지수': 1,
#  '경신': 1,
#  '경쟁사': 3,
#  '경제': 18,
#  '경제성장률': 2,
#  '경제지표': 8,
#  '경찰': 4,
#  '경찰관': 1,
#  '경험': 1,
#  '경호': 2,
#  '경호수위': 1,
#  '계속': 1,
#  '계약': 7,
#  '계엄': 2,
#  '계열': 1,
#  '계열분리': 4,
#  '계열사': 1,
#  '계획': 2,
#  '계획했다면': 1,
#  '고각': 3,
#  '고강도': 1,
#  '고객사에': 1,
#  '고꾸라진': 1,
#  '고대안암': 1,
#  '고도': 1,
#  '고려아연': 13,
#  '고려아연에': 1,
#  '고려요인': 1,
#  '고발': 2,
#  '고병원성': 2,
#  '고속버스': 2,
#  '고속버스가': 1,
#  '고수': 1,
#  '고용': 5,
#  '고용보고서': 1,
#  '고용지표가': 1,
#  '고위급': 2,
#  '고척교': 1,
#  '고체연료': 1,
#  '고통스러운': 1,
#  '고통스런': 1,
#  '고향': 1,
#  '골프장': 1,
#  '공개': 8,
#  '공개된': 1,
#  '공개매수': 2,
#  '공개활동': 1,
#  '공격': 15,
#  '공격대상': 1,
#  '공격에': 2,
#  '공격으로': 2,
#  '공격은': 1,
#  '공공': 1,
#  '공공장소흉기소지죄': 1,
#  '공관위서': 1,
#  '공군': 1,
#  '공급계약': 1,
#  '공급대책': 2,
#  '공동': 1,
#  '공동대': 1,
#  '공동대응': 1,
#  '공동정권': 1,
#  '공명': 7,
#  '공모주': 1,
#  '공수처': 2,
#  '공습': 9,
#  '공습으로': 1,
#  '공습작전': 1,
#  '공시': 1,
#  '공식': 1,
#  '공식발표': 2,
#  '공영': 1,
#  '공영주차장': 1,
#  '공유': 1,
#  '공장': 1,
#  '공장서': 1,
#  '공정위': 1,
#  '공중서': 1,
#  '공중협박죄': 1,
#  '공직선거법': 3,
#  '공직선거법위반': 1,
#  '공천': 4,
#  '공천개입': 2,
#  '공천지시': 1,
#  '공항방향': 1,
#  '과반': 7,
#  '과반수': 1,
#  '과제': 1,
#  '과제는': 1,
#  '과징금': 1,
#  '관건': 4,
#  '관계': 1,
#  '관련': 10,
#  '관리': 4,
#  '관리해야': 2,
#  '관망세': 1,
#  '관심': 3,
#  '관장': 1,
#  '관저': 2,
#  '관절': 1,
#  '관철될': 1,
#  '광주': 1,
#  '굉장히': 1,
#  '교도': 1,
#  '교류': 1,
#  '교류해': 1,
#  '교민': 1,
#  '교수': 1,
#  '교육': 1,
#  '교육부': 4,
#  '교전지역': 2,
#  '교전해': 1,
#  '교제살인': 1,
#  '교체': 3,
#  '교통사고': 2,
#  '구로': 1,
#  '구사': 1,
#  '구속': 2,
#  '구속되면': 1,
#  '구속에': 1,
#  '구속영장': 1,
#  '구연경': 1,
#  '구조': 1,
#  '구조개혁': 1,
#  '구조전환': 1,
#  '구조전환에': 1,
#  '구축할': 1,
#  '구형': 8,
#  '국가안보': 1,
#  '국가안보실장': 1,
#  '국감': 1,
#  '국내': 4,
#  '국내법상': 1,
#  '국내총생산': 1,
#  '국립대': 1,
#  '국면': 1,
#  '국무위원': 1,
#  '국민': 9,
#  '국방부': 2,
#  '국방장관회의': 2,
#  '국방정보본부': 7,
#  '국세': 1,
#  '국정원': 30,
#  '국정지지율': 1,
#  '국제': 2,
#  '국제규범': 1,
#  '국제법': 1,
#  '국제법적': 2,
#  '국제유가': 1,
#  '국채금리': 2,
#  '국채금리도': 1,
#  '국회': 2,
#  '국회법': 1,
#  '국회상황': 1,
#  '국회의원': 1,
#  '국힘': 1,
#  '군기지에': 1,
#  '군부': 1,
#  '군사': 4,
#  '군사목표물': 2,
#  '군사목표물만': 1,
#  '군사밀착': 1,
#  '군사상호지원': 1,
#  '군사시설': 1,
#  '군사지원': 1,
#  '군사협력': 5,
#  '군소식통': 1,
#  '군시설에': 1,
#  '군용어': 1,
#  '군의': 1,
#  '군인': 3,
#  '굳건히': 1,
#  '권한': 1,
#  '권한대행에': 1,
#  '귀기울이겠다': 2,
#  '귀기울일': 1,
#  '귀순': 1,
#  '귀환': 1,
#  '규모': 4,
#  '규범에': 2,
#  '규제': 1,
#  '규칙안': 3,
#  '규탄': 3,
#  '규탄대회에': 1,
#  '규탄이': 1,
#  '그랬다': 1,
#  '그런': 3,
#  '그저': 1,
#  '그쳐': 1,
#  '극대노': 1,
#  '극복': 1,
#  '극초음속': 1,
#  '근본적': 1,
#  '글로벌': 1,
#  '금감원': 5,
#  '금리': 2,
#  '금리인하': 3,
#  '금리인하에': 1,
#  '금사5터널': 1,
#  '금수품': 1,
#  '금융사고': 3,
#  '금일': 1,
#  '금자탑': 2,
#  '금지': 2,
#  '금투세': 1,
#  '급등': 8,
#  '급등했던': 1,
#  '급락': 3,
#  '급부상': 1,
#  '급여': 1,
#  '급작스런': 1,
#  '기각': 3,
#  '기능': 1,
#  '기대감': 4,
#  '기록': 1,
#  '기상속보': 1,
#  '기술': 1,
#  '기습': 1,
#  '기아': 8,
#  '기아도': 1,
#  '기아에': 1,
#  '기억': 1,
#  '기억에': 1,
#  '기업가치': 1,
#  '기울일': 1,
#  '기자단': 1,
#  '기자들이': 1,
#  '기재부': 5,
#  '기재오류': 1,
#  '기존': 1,
#  '기준금리': 1,
#  '기폭제': 1,
#  '기회로': 1,
#  '긴급': 1,
#  '긴급공사': 1,
#  '긴밀히': 1,
#  '긴장': 1,
#  '김건희': 3,
#  '김레아': 1,
#  '김범수': 5,
#  '김선기': 1,
#  '김선빈': 1,
#  '김수미': 18,
#  '김수미씨': 1,
#  '김여사': 1,
#  '김여사가': 1,
#  '김여정': 2,
#  '김영복': 2,
#  '김영복이': 1,
#  '김영선': 5,
#  '김영선이': 1,
#  '김용현': 2,
#  '김정은': 9,
#  '김정은만': 4,
#  '김주애': 3,
#  '김태군': 2,
#  '김태흠': 1,
#  '김택규': 3,
#  '김포': 1,
#  '김혜경': 3,
#  '김혜경에': 3,
#  '깊은': 1,
#  '까지': 1,
#  '꺾고': 2,
#  '꺾일': 1,
#  '껑충': 3,
#  '꿈틀하는': 1,
#  '끌어안고': 1,
#  '끝나': 1,
#  '끝내': 1,
#  '끝없이': 1,
#  '나갈': 1,
#  '나스닥': 10,
#  '나스닥도': 2,
#  '나스닥만': 1,
#  '나스닥지수': 3,
#  '나스랄라': 1,
#  '나올': 1,
#  '나임': 1,
#  '나토': 14,
#  '나홀로': 1,
#  '낙선': 1,
#  '낙하': 2,
#  '낙하물': 2,
#  '난개발': 1,
#  '난임': 1,
#  '날벼락': 2,
#  '날쭉': 1,
#  '남남갈등': 1,
#  '남남갈등과': 1,
#  '남부': 2,
#  '남북': 1,
#  '남서부': 2,
#  '남성': 1,
#  '남았다': 1,
#  '남을': 1,
#  '남자': 1,
#  '남청라ic': 1,
#  '남한은': 4,
#  '납북자가족모임': 2,
#  '내각에': 1,
#  '내년': 10,
#  '내달': 5,
#  '내달라': 1,
#  '내도록': 1,
#  '내린': 1,
#  '내릴까': 1,
#  '내부': 2,
#  '내부결속': 1,
#  '내부에': 1,
#  '내부통제': 1,
#  '내세워': 1,
#  '내수': 6,
#  '내수회복': 1,
#  '내야': 1,
#  '내에': 1,
#  '내용': 1,
#  '내주': 1,
#  '내포종합병원': 1,
#  '너무': 1,
#  '넘게': 1,
#  '넘어': 4,
#  '넘어가고': 1,
#  '네덜란드': 2,
#  '네타냐후': 1,
#  '넥스턴바이오': 1,
#  '노동자': 3,
#  '노란무늬영': 1,
#  '노력': 2,
#  '노선': 1,
#  '노소영': 2,
#  '노조': 1,
#  '녹음': 1,
#  '녹취': 2,
#  '녹취록': 1,
#  '논란': 2,
#  '논산서': 1,
#  '논의': 13,
#  '농도': 2,
#  '농어촌버스': 1,
#  '높고': 1,
#  '높을': 4,
#  '높일': 2,
#  '놓기': 1,
#  '놓쳐': 1,
#  '뇌물': 2,
#  '누렸으면': 1,
#  '누적': 1,
#  '눈앞': 1,
#  '뉴욕': 1,
#  '뉴욕다이어리': 1,
#  '뉴욕증시': 18,
#  '뉴욕채권': 4,
#  '뉴욕환시': 1,
#  '능력': 1,
#  '늦게': 1,
#  '다마스커스': 1,
#  '다마스쿠스서': 1,
#  '다섯': 1,
#  '다시': 1,
#  '다우': 3,
#  '다우는': 1,
#  '다우지수만': 1,
#  '다음주': 3,
#  '다저스': 2,
#  '다중추돌사고': 1,
#  '단계': 1,
#  '단계별': 1,
#  '단계별로': 2,
#  '단계적': 1,
#  '단독': 2,
#  '단독처리': 5,
#  '단말기유통법': 1,
#  '단행': 4,
#  '달라': 1,
#  '달만에': 1,
#  '달성': 5,
#  '담달': 1,
#  '담당': 1,
#  '담양군수': 2,
#  '담은': 1,
#  '당국': 3,
#  '당국자': 1,
#  '당기순이익': 1,
#  '당내': 1,
#  '당대표는': 1,
#  '당선되면': 3,
#  '당선무효형': 2,
#  '당선시': 2,
#  '당선인': 2,
#  '당선자': 1,
#  '당시': 1,
#  '당에서': 1,
#  '당연히': 1,
#  '당정': 6,
#  '당정관계': 2,
#  '당첨번호': 1,
#  '대가': 1,
#  '대공': 1,
#  '대구경북': 1,
#  '대구서': 1,
#  '대남': 1,
#  '대내외': 1,
#  '대대적': 1,
#  '대림아파트': 1,
#  '대만': 2,
#  '대망의': 1,
#  '대법서': 1,
#  '대법원': 1,
#  '대변인': 1,
#  '대부분': 1,
#  '대북': 1,
#  '대북독자제재': 2,
#  '대북방송': 1,
#  '대북송금': 2,
#  '대북전단': 3,
#  '대비': 10,
#  '대상': 3,
#  '대선': 6,
#  '대선과': 6,
#  '대선서': 3,
#  '대승': 1,
#  '대외경제': 3,
#  '대응': 16,
#  '대응방안': 1,
#  '대응의지': 2,
#  '대응조치': 1,
#  '대응하면': 1,
#  '대응할': 2,
#  '대전시의회': 1,
#  '대책': 2,
#  '대통령': 23,
#  '대통령과': 6,
#  '대통령실': 50,
#  '대통령실에': 1,
#  '대통령에': 1,
#  '대표': 6,
#  '대표단': 2,
#  '대표로': 1,
#  '대표에': 1,
#  '대표직': 1,
#  '대표팀': 1,
#  '대피': 1,
#  '대학': 2,
#  '대한': 3,
#  '대형': 1,
#  '대화했다': 1,
#  '더욱': 1,
#  '덮쳐': 2,
#  '도로': 1,
#  '도마에': 1,
#  '도발': 7,
#  '도발에': 1,
#  '도약': 4,
#  '도용해': 1,
#  '도입': 1,
#  '독자편집위원회': 1,
#  '돈봉투': 2,
#  '돌아갈': 2,
#  '돌파': 5,
#  '돌파해야': 1,
#  '동결': 1,
#  '동률': 1,
#  '동맹에': 1,
#  '동맹휴학': 2,
#  '동반': 2,
#  '동반자': 1,
#  '동부': 1,
#  '동부로': 1,
#  '동시에': 2,
#  '동요': 1,
#  '동해상': 1,
#  '동해상에': 1,
#  '동해상으로': 2,
#  '동해서': 1,
#  '동행명령': 1,
#  ...}

# %%
all_text
# Out:
# '[속보] 부산 미군기지에서 불...대응 1단계 발령 [속보] 尹 “우크라 살상무기 지원, 北 활동 따라 검토” [속보] 러 하원, 북러 조약 만장일치 비준 [속보] 우크라 "북한군 2000명, 훈련 마치고 러 서부로 이동" [속보]3분기 韓경제 0.1% 성장…예상 밖 성장쇼크 [속보] 검찰, \'공직선거법 위반\' 김혜경 벌금 300만원 재구형 [속보]상급종합병원 구조전환에 세브란스·고대안암 등 8개 병원 선정 [속보] 검찰 \'공직선거법 위반\' 김혜경에 벌금 300만원 재구형 [속보]SK하이닉스 3분기 영업익 7조...반도체이익 삼성전자 넘어 [속보] SK하이닉스 지붕 뚫었다...역대 최대 영업이익 7조300억 원으로 신... [속보] 상급병원 구조전환 지원사업에 세브란스 등 8개 병원 1차 선정 [속보]SK하이닉스 3분기 영업익 7조...반도체이익 삼성전자 넘어 [속보] 美 “북한군 3천명 러서 훈련중…우크라전 투입땐 정당한 표적” [속보] SK하이닉스 지붕 뚫었다...역대 최대 영업이익 7조300억 원으로 신... [속보] 부산 주한미군 55보급창서 큰 불…대응 2단계 [속보] 윤 대통령 "北 러시아 파병은 도발…좌시하지 않을 것" [속보] ‘HBM 매출 330% 증가’ SK하이닉스, 3분기 영업익 7조300억원 ‘... [속보] 검찰, \'공직선거법 위반\' 김혜경 3백만 원 구형 [속보] 이병노 담양군수 항소심도 당선무효형 [속보] 法 "공정위, 로톡 징계 변협 과징금 취소해야" [속보]‘김 여사 비난 전단’ 담은 오물풍선 北 살포…대통령실 청사에... [속보] 3분기 실질GDP 성장률 0.1%에 그쳐···수출은 0.4% 감소 [속보] 검찰 \'공직선거법위반\' 김혜경 벌금 300만원 구형 [속보]한동훈 “당 대표, 원내든 원외든 당 전체업무 총괄…특별감찰관... [속보] 현