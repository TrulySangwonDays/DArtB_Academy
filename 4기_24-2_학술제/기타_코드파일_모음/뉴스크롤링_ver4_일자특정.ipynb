# %%
# `한글 지원 라이브러리 설치`
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# Out:
# Requirement already satisfied: koreanize-matplotlib in /opt/anaconda3/lib/python3.12/site-packages (0.1.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (from koreanize-matplotlib) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->koreanize-matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)

# %% [markdown]
# ## chromedriver 뉴스기사 크롤링

# %% [markdown]
# https://somjang.tistory.com/entry/MAC-OSX-개발자를-확인할-수-없기-때문에-chromedriver을를-열-수-없습니다-해결-방법

# %% [markdown]
# ### 사용할 날짜 리스트

# %%
# 연도
year = ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']

# 월
month = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

# 1~8일   # 9~15일   # 16~23일   # 24~31일
start_d = ["01", "09", "16", "24"]
end_d = ["08", "15", "23", "31"]

# 총 480개 조합

# %% [markdown]
# ### 최종 크롤링 코드
# - 날짜란에 2주전, 3주전 이런 표시 때문에 하루단위로 csv저장

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import urllib.parse
import time
import pandas as pd

#####################################################
# 검색어, 연도, 월 설정
text = "속보 한강 노벨"
year = ['2024']
month = ['10']
#####################################################

# ChromeDriver 경로 설정
driver_path = "/Users/leesangwon/Desktop/chromedriver-mac-arm64/chromedriver"  # 여기에 ChromeDriver의 경로를 입력
service = Service(driver_path)

# 웹드라이버 초기화
driver = webdriver.Chrome(service=service)

# 연도, 월을 순회하며 크롤링
for y in year:
    for m in month:
        # 월의 마지막 날짜 계산
        if m == '01' or m == '03' or m == '05' or m == '07' or m == '08' or m == '10' or m == '12':
            last_day = 31
        elif m == '04' or m == '06' or m == '09' or m == '11':
            last_day = 30
        else:  # 2월 (윤년은 29일)
            last_day = 29

        # 하루 단위로 크롤링
        for day in range(1, last_day + 1):
            start_d = str(day).zfill(2)  # 01, 02, ..., 31 형태로 만들어줌
            end_d = start_d  # 하루 단위로 크롤링하므로 시작일과 종료일이 같음

            # URL 생성
            encoded_text = urllib.parse.quote(text)  # 검색어를 url 인코딩
            url = f"https://search.naver.com/search.naver?where=news&query={encoded_text}&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds={y}.{m}.{start_d}&de={y}.{m}.{end_d}&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Ar%2Cp%3Afrom{y}{m}{start_d}to{y}{m}{end_d}&is_sug_officeid=0&office_category=0&service_area=0"

            # 페이지 열기
            driver.get(url)

            # 스크롤 1~2번 내리기
            last_height = driver.execute_script("return document.body.scrollHeight")
            for _ in range(20):  # 1~2번 스크롤 내리기
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(1.5)
                new_height = driver.execute_script("return document.body.scrollHeight")
                if new_height == last_height:
                    break
                last_height = new_height

            # 기사 제목, 날짜, 스크립트 크롤링
            titles = driver.find_elements(By.CSS_SELECTOR, ".news_tit")
            dates = driver.find_elements(By.CSS_SELECTOR, ".info_group > span")
            scripts = driver.find_elements(By.CSS_SELECTOR, ".dsc_txt_wrap")
            press = driver.find_elements(By.CSS_SELECTOR, ".info_group > a.press")

            # 하루 단위로 데이터를 저장할 리스트
            all_data = []

            # 상위 30개 기사만 저장
            for title, date, script, p in zip(titles[:30], dates[:30], scripts[:30], press[:30]):
                all_data.append({
                    "Title": title.text,
                    "Date": date.text,
                    "Press": p.text,
                    "Description": script.text
                })

            # 하루 단위로 CSV 파일로 저장
            df_day = pd.DataFrame(all_data)
            df_day.to_csv(f"/Users/leesangwon/Downloads/{text}_{y}{m}{start_d}_news_data.csv", index=False)

# 드라이버 종료
driver.quit()

# %%
### 30개 넘는 일자에 대한 집중 크롤링 코드

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import urllib.parse
import time
import pandas as pd

#####################################################
# 검색어, 연도, 월 설정
text = "속보 한강 노벨"
year = ['2024']
month = ['10']
#####################################################

# ChromeDriver 경로 설정
driver_path = "/Users/leesangwon/Desktop/chromedriver-mac-arm64/chromedriver"  # 여기에 ChromeDriver의 경로를 입력
service = Service(driver_path)

# 웹드라이버 초기화
driver = webdriver.Chrome(service=service)

# 연도, 월을 순회하며 크롤링
for y in year:
    for m in month:
        # 월의 마지막 날짜 계산
        if m == '01' or m == '03' or m == '05' or m == '07' or m == '08' or m == '10' or m == '12':
            last_day = 11
        elif m == '04' or m == '06' or m == '09' or m == '11':
            last_day = 15
        else:  # 2월 (윤년은 29일)
            last_day = 29

        # 하루 단위로 크롤링
        for day in range(10, last_day + 1):
            start_d = str(day).zfill(2)  # 01, 02, ..., 31 형태로 만들어줌
            end_d = start_d  # 하루 단위로 크롤링하므로 시작일과 종료일이 같음

            # URL 생성
            encoded_text = urllib.parse.quote(text)  # 검색어를 url 인코딩
            url = f"https://search.naver.com/search.naver?where=news&query={encoded_text}&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds={y}.{m}.{start_d}&de={y}.{m}.{end_d}&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Ar%2Cp%3Afrom{y}{m}{start_d}to{y}{m}{end_d}&is_sug_officeid=0&office_category=0&service_area=0"

            # 페이지 열기
            driver.get(url)

            # 스크롤을 끝까지 내리기
            last_height = driver.execute_script("return document.body.scrollHeight")
            while True:
                # 페이지 끝까지 스크롤
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(1.5)
                new_height = driver.execute_script("return document.body.scrollHeight")
                if new_height == last_height:  # 더 이상 스크롤할 곳이 없으면 종료
                    break
                last_height = new_height

            # 기사 제목, 날짜, 스크립트 크롤링
            titles = driver.find_elements(By.CSS_SELECTOR, ".news_tit")
            dates = driver.find_elements(By.CSS_SELECTOR, ".info_group > span")
            scripts = driver.find_elements(By.CSS_SELECTOR, ".dsc_txt_wrap")
            press = driver.find_elements(By.CSS_SELECTOR, ".info_group > a.press")

            # 하루 단위로 데이터를 저장할 리스트
            all_data = []

            # 상위 30개 기사만 저장
            for title, date, script, p in zip(titles, dates, scripts, press):
                all_data.append({
                    "Title": title.text,
                    "Date": date.text,
                    "Press": p.text,
                    "Description": script.text
                })

            # 하루 단위로 CSV 파일로 저장
            df_day = pd.DataFrame(all_data)
            df_day.to_csv(f"/Users/leesangwon/Downloads/{text}_{y}{m}{start_d}_news_data.csv", index=False)

# 드라이버 종료
driver.quit()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/Users/leesangwon/Downloads/보도 빈도 [속보 한강 노벨] 크롤링/속보 한강 노벨_일별빈도.csv')

# 'Date' 열을 datetime 형식으로 변환
df['Date'] = pd.to_datetime(df['Date'], format='%Y.%m.%d')

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['freq'], marker='o', linestyle='-', color='g')

# 제목과 축 라벨 설정
plt.title('[속보 한강 노벨 ] 일별 보도 빈도', fontsize=16)
plt.xlabel('날짜', fontsize=12)
plt.ylabel('freq', fontsize=12)

# 날짜 형식 설정
plt.xticks(rotation=45)
plt.grid(True)

# 그래프 출력
plt.tight_layout()
plt.show()

# %% [markdown]
# # 관련 기사 급증하는 일자 특정

# %%
import pandas as pd
df = pd.read_csv('/Users/leesangwon/Downloads/news_data_2.csv')
df
# Out:
#                                          Title         Date       Press  \
# 0                [속보] 미·러, '우크라 사태' 안보 협상 '타결'  2022.01.11.        천지일보
# 1    중·러 견제 동맹결집 집중… 미사일 위협에도 대북정책 뒷전 [심층기획...       A8면 1단  세계일보언론사 선정
# 2           [속보] 바이든 "우크라 침공은 러시아에 재앙"…강력제재 경고  2022.01.18.        신아일보
# 3               [속보] 美, 우크라 미 대사관 직원 가족에 철수 명령  2022.01.24.  국민일보언론사 선정
# 4     [속보] 美 "러, 우크라 겨냥 상당 규모 '군사행동 계획' 보고 있어"  2022.01.24.        천지일보
# ..                                         ...          ...         ...
# 267         [속보] 젤렌스키 우크라 대통령, 尹과 통화후 트윗에 올린 글  2022.03.29.  중앙일보언론사 선정
# 268                      [속보] 우크라-러시아 5차 협상 끝나  2022.03.29.        천지일보
# 269             [속보]전쟁 끝나나…러시아 “‘두 발’ 양보하고 있다”  2022.03.29.  서울신문언론사 선정
# 270     [속보] 러시아 본토 무기고 폭발, 우크라 미사일 공격 추정 (영상)  2022.03.30.        서울신문
# 271             [속보] 외교부 “우크라 의용군 간 한국인 1명 출국”  2022.03.31.  서울신문언론사 선정
#
#                                            Description
# 0                        미·러, '우크라 사태' 안보 협상 '타결' 천지일보
# 1    바이든, 美 우선주의 지우기 초점 우크라 사태·인도태평양 갈등에 나토·오커스 등 동...
# 2                        바이든 "우크라 침공은 러시아에 재앙"…강력제재 경고
# 3    미국 정부가 우크라이나의 미국대사관 직원 가족에게 철수 명령을 내렸다고 AP통신과 ...
# 4        [속보] 美 "러, 우크라 겨냥 상당 규모 '군사행동 계획' 보고 있어" 천지일보
# ..                                                 ...
# 267  윤석열 20대 대통령 당선인이 볼로디미르 젤렌스키 우크라이나 대통령과 전화통화를 했...
# 268                              우크라-러시아 5차 협상 끝나 천지일보
# 269  터키 이스탄불에서 열린 러시아와 우크라이나 간 5차 평화협상이 종료됐다. 양측 대표...
# 270  29일(이하 현지시간) 우크라이나 매체 ‘포커스’는 러시아 서부 벨고로드 외곽의 한...
# 271  “허가없는 체류 6명…그중 한 명 출국” “이근 등 9명 우크라 입국, 현재 5명만...
#
# [272 rows x 4 columns]

# %%
date_group = df.groupby('Date').size().reset_index(name='Count')
date_group.head()
# Out:
#           Date  Count
# 0  2022.01.11.      1
# 1  2022.01.18.      1
# 2  2022.01.24.      4
# 3  2022.02.05.      1
# 4  2022.02.06.      2

# %%
import matplotlib.pyplot as plt

# 날짜 데이터를 시계열로 변환
date_group['Date'] = pd.to_datetime(date_group['Date'], errors='coerce')
date_group = date_group.dropna(subset=['Date'])  # 변환에 실패한 날짜 제거

# 꺾은선 그래프 시각화
plt.figure(figsize=(14, 6))
plt.plot(date_group['Date'], date_group['Count'], marker='o')
plt.title('"[속보] 우크라" 일별 보도 빈도수', fontsize=20)
plt.xlabel('일자', fontsize=12)
plt.ylabel('횟수', fontsize=12)
plt.xticks(rotation=45)
plt.grid(visible=True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# 2022년 2월 24일 뉴스 보도가 급증했음 = 러시아의 침공날짜!
# 보도가 나온 날짜 vs. 보도가 떠들석하다가 점점 사그라드는 시점(약 3월 7일 정도)의 주식 수익률을 알아보자

# %% [markdown]
# # 특정된 일자 기준으로 주가 수익률 확인 및 라벨링

# %%
import yfinance as yf

start = '2022-02-15'
end = '2022-03-15'

tickers = pd.read_csv(f'/Users/leesangwon/Downloads/kospi200_tickers_241111.csv', encoding="CP949")
# 티커 칼럼 리스트화
tickers_list = tickers['티커'].tolist() if '티커' in tickers.columns else tickers.iloc[:, 0].tolist()
symbol = tickers_list

stock = yf.download(symbol, start, end)
stock = stock['Adj Close']

stock
# Out:
# [*********************100%***********************]  202 of 202 completed
#
# 4 Failed downloads:
# ['457190.KS', '450080.KS', '489790.KS', '454910.KS']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2022-02-15 -> 2022-03-15) (Yahoo error = "Data doesn\'t exist for startDate = 1644850800, endDate = 1647270000")')
# Ticker                        000080.KS     000100.KS      000120.KS  \
# Date
# 2022-02-15 00:00:00+00:00  31353.052734  49917.644531  120849.632812
# 2022-02-16 00:00:00+00:00  31955.105469  51170.058594  122335.484375
# 2022-02-17 00:00:00+00:00  32186.662109  50633.308594  121840.195312
# 2022-02-18 00:00:00+00:00  32696.091797  50543.847656  123326.054688
# 2022-02-21 00:00:00+00:00  32696.091797  50543.847656  123326.054688
# 2022-02-22 00:00:00+00:00  32696.091797  50543.847656  123326.054688
# 2022-02-23 00:00:00+00:00  32696.091797  50543.847656  123326.054688
# 2022-02-24 00:00:00+00:00  32927.652344  50186.019531  122335.484375
# 2022-02-25 00:00:00+00:00  32973.964844  50633.308594  122335.484375
# 2022-02-28 00:00:00+00:00  32973.964844  50633.308594  122335.484375
# 2022-03-02 00:00:00+00:00  33066.585938  51706.808594  129764.765625
# 2022-03-03 00:00:00+00:00  33066.585938  51706.808594  130260.046875
# 2022-03-04 00:00:00+00:00  33066.585938  51706.808594  130260.046875
# 2022-03-07 00:00:00+00:00  32973.964844  51348.976562  128774.195312
# 2022-03-08 00:00:00+00:00  32140.353516  51796.265625  126793.046875
# 2022-03-10 00:00:00+00:00  32140.353516  51796.265625  126793.046875
# 2022-03-11 00:00:00+00:00  34224.382812  51796.265625  126793.046875
# 2022-03-14 00:00:00+00:00  34409.628906  51617.351562  136203.468750
#
# Ticker                         000150.KS     000210.KS     000240.KS  \
# Date
# 2022-02-15 00:00:00+00:00   82645.695312  53747.910156  12032.377930
# 2022-02-16 00:00:00+00:00   84379.531250  54616.367188  12122.507812
# 2022-02-17 00:00:00+00:00   84957.468750  55581.320312  12077.443359
# 2022-02-18 00:00:00+00:00   92952.335938  59248.144531  12212.638672
# 2022-02-21 00:00:00+00:00   92952.335938  59248.144531  12212.638672
# 2022-02-22 00:00:00+00:00   92952.335938  59248.144531  12212.638672
# 2022-02-23 00:00:00+00:00   92952.335938  59248.144531  12212.638672
# 2022-02-24 00:00:00+00:00   92085.421875  57607.726562  11761.988281
# 2022-02-25 00:00:00+00:00  101139.843750  57318.242188  11942.248047
# 2022-02-28 00:00:00+00:00  101139.843750  57318.242188  11942.248047
# 2022-03-02 00:00:00+00:00  107400.882812  57800.718750  11852.118164
# 2022-03-03 00:00:00+00:00  116070.015625  59055.156250  12032.377930
# 2022-03-04 00:00:00+00:00  116070.015625  59055.156250  12032.377930
# 2022-03-07 00:00:00+00:00  115588.398438  55388.332031  11716.921875
# 2022-03-08 00:00:00+00:00  109808.976562  55098.843750  11671.857422
# 2022-03-10 00:00:00+00:00  109808.976562  56932.257812  11671.857422
# 2022-03-11 00:00:00+00:00  109808.976562  57125.250000  11671.857422
# 2022-03-14 00:00:00+00:00  122812.671875  57221.746094  11852.118164
#
# Ticker                        000270.KS      000660.KS    000670.KS  \
# Date
# 2022-02-15 00:00:00+00:00  70153.242188  123415.570312  620617.0625
# 2022-02-16 00:00:00+00:00  71870.914062  126816.781250  624477.8125
# 2022-02-17 00:00:00+00:00  71870.914062  129246.226562  618686.6875
# 2022-02-18 00:00:00+00:00  71147.679688  127788.562500  626408.1875
# 2022-02-21 00:00:00+00:00  71147.679688  127788.562500  626408.1875
# 2022-02-22 00:00:00+00:00  71147.679688  127788.562500  626408.1875
# 2022-02-23 00:00:00+00:00  71147.679688  127788.562500  626408.1875
# 2022-02-24 00:00:00+00:00  66356.289062  119042.578125  637025.2500
# 2022-02-25 00:00:00+00:00  66717.906250  119528.453125  629303.7500
# 2022-02-28 00:00:00+00:00  66717.906250  119528.453125  629303.7500
# 2022-03-02 00:00:00+00:00  65181.042969  121472.015625  645712.0000
# 2022-03-03 00:00:00+00:00  66717.906250  125359.117188  642816.4375
# 2022-03-04 00:00:00+00:00  66717.906250  125359.117188  642816.4375
# 2022-03-07 00:00:00+00:00  64277.003906  116127.257812  632199.3125
# 2022-03-08 00:00:00+00:00  62920.953125  114669.585938  620617.0625
# 2022-03-10 00:00:00+00:00  62920.953125  114669.585938  620617.0625
# 2022-03-11 00:00:00+00:00  62920.953125  114669.585938  620617.0625
# 2022-03-14 00:00:00+00:00  62197.718750  112726.023438  643781.6250
#
# Ticker                        000720.KS  ...  373220.KS     375500.KS  \
# Date                                     ...
# 2022-02-15 00:00:00+00:00  39659.300781  ...   451500.0  53496.164062
# 2022-02-16 00:00:00+00:00  40383.890625  ...   455500.0  54455.738281
# 2022-02-17 00:00:00+00:00  40625.421875  ...   454500.0  55655.203125
# 2022-02-18 00:00:00+00:00  40625.421875  ...   454500.0  57334.453125
# 2022-02-21 00:00:00+00:00  40625.421875  ...   453000.0  59493.492188
# 2022-02-22 00:00:00+00:00  40625.421875  ...   440000.0  59493.492188
# 2022-02-23 00:00:00+00:00  40625.421875  ...   440000.0  59493.492188
# 2022-02-24 00:00:00+00:00  40866.949219  ...   416500.0  58533.921875
# 2022-02-25 00:00:00+00:00  41156.789062  ...   420000.0  59253.601562
# 2022-02-28 00:00:00+00:00  41156.789062  ...   420000.0  59253.601562
# 2022-03-02 00:00:00+00:00  42219.523438  ...   434000.0  61652.531250
# 2022-03-03 00:00:00+00:00  43910.234375  ...   437000.0  63091.890625
# 2022-03-04 00:00:00+00:00  43910.234375  ...   428500.0  62851.996094
# 2022-03-07 00:00:00+00:00  44006.847656  ...   414000.0  62851.996094
# 2022-03-08 00:00:00+00:00  42702.582031  ...   410500.0  61652.531250
# 2022-03-10 00:00:00+00:00  42702.582031  ...   410500.0  63811.570312
# 2022-03-11 00:00:00+00:00  47726.417969  ...   391000.0  64291.351562
# 2022-03-14 00:00:00+00:00  47774.722656  ...   363500.0  65250.929688
#
# Ticker                     377300.KS      383220.KS  402340.KS  450080.KS  \
# Date
# 2022-02-15 00:00:00+00:00   127500.0  170736.578125    51700.0        NaN
# 2022-02-16 00:00:00+00:00   132500.0  167438.250000    54700.0        NaN
# 2022-02-17 00:00:00+00:00   133500.0  163169.843750    54200.0        NaN
# 2022-02-18 00:00:00+00:00   140000.0  163557.890625    54200.0        NaN
# 2022-02-21 00:00:00+00:00   140500.0  160259.562500    55800.0        NaN
# 2022-02-22 00:00:00+00:00   139000.0  160259.562500    55800.0        NaN
# 2022-02-23 00:00:00+00:00   139500.0  160259.562500    55800.0        NaN
# 2022-02-24 00:00:00+00:00   135000.0  158707.421875    55300.0        NaN
# 2022-02-25 00:00:00+00:00   144000.0  163557.890625    57300.0        NaN
# 2022-02-28 00:00:00+00:00   149500.0  163557.890625    57300.0        NaN
# 2022-03-02 00:00:00+00:00   148000.0  166274.140625    54100.0        NaN
# 2022-03-03 00:00:00+00:00   147000.0  167632.281250    55100.0        NaN
# 2022-03-04 00:00:00+00:00   147000.0  164139.937500    53000.0        NaN
# 2022-03-07 00:00:00+00:00   134000.0  159095.453125    50700.0        NaN
# 2022-03-08 00:00:00+00:00   128500.0  159483.484375    49250.0        NaN
# 2022-03-10 00:00:00+00:00   128500.0  159483.484375    49250.0        NaN
# 2022-03-11 00:00:00+00:00   135000.0  155021.062500    51400.0        NaN
# 2022-03-14 00:00:00+00:00   136000.0  136783.281250    52200.0        NaN
#
# Ticker                     454910.KS  457190.KS  489790.KS        ^KS11
# Date
# 2022-02-15 00:00:00+00:00        NaN        NaN        NaN  2676.540039
# 2022-02-16 00:00:00+00:00        NaN        NaN        NaN  2729.679932
# 2022-02-17 00:00:00+00:00        NaN        NaN        NaN  2744.090088
# 2022-02-18 00:00:00+00:00        NaN        NaN        NaN  2744.520020
# 2022-02-21 00:00:00+00:00        NaN        NaN        NaN  2743.800049
# 2022-02-22 00:00:00+00:00        NaN        NaN        NaN  2706.790039
# 2022-02-23 00:00:00+00:00        NaN        NaN        NaN  2719.530029
# 2022-02-24 00:00:00+00:00        NaN        NaN        NaN  2648.800049
# 2022-02-25 00:00:00+00:00        NaN        NaN        NaN  2676.760010
# 2022-02-28 00:00:00+00:00        NaN        NaN        NaN  2699.179932
# 2022-03-02 00:00:00+00:00        NaN        NaN        NaN  2703.520020
# 2022-03-03 00:00:00+00:00        NaN        NaN        NaN  2747.080078
# 2022-03-04 00:00:00+00:00        NaN        NaN        NaN  2713.429932
# 2022-03-07 00:00:00+00:00        NaN        NaN        NaN  2651.310059
# 2022-03-08 00:00:00+00:00        NaN        NaN        NaN  2622.399902
# 2022-03-10 00:00:00+00:00        NaN        NaN        NaN  2680.320068
# 2022-03-11 00:00:00+00:00        NaN        NaN        NaN  2661.280029
# 2022-03-14 00:00:00+00:00        NaN        NaN        NaN  2645.649902
#
# [18 rows x 202 columns]

# %%
# 인덱스를 datetime 형식으로 변환
stock.index = pd.to_datetime(stock.index)

before = stock.loc["2022-02-24"]
after = stock.loc["2022-03-07"]

# 수익률 계산
returns = round((after - before) / before * 100, 3)

# 수익률 데이터를 데이터프레임으로 변환
returns_df = pd.DataFrame(returns, columns=["Return"])

# 인덱스를 칼럼으로 변환하여 "Ticker"라는 새 칼럼 생성
returns_df.reset_index(inplace=True)
returns_df.rename(columns={"index": "Ticker"}, inplace=True)

# 티커와 종목명 간의 매핑 딕셔너리 생성
ticker_to_name = dict(zip(tickers['티커'], tickers['종목명']))

# 티커를 종목명으로 대치
returns_df["Ticker"] = returns_df["Ticker"].map(ticker_to_name)

# 수익률을 내림차순으로 정렬
returns_df.sort_values(by="Return", ascending=False, inplace=True)

# 결과 출력
returns_df
# Out:
#            Ticker  Return
# 159           덴티움  31.204
# 3              두산  25.523
# 150         씨에스윈드  25.192
# 24         세아제강지주  22.936
# 137        LIG넥스원  21.746
# ..            ...     ...
# 155       메리츠금융지주 -14.805
# 197        에코프로머티     NaN
# 198        두산로보틱스     NaN
# 199     이수스페셜티케미컬     NaN
# 200  한화인더스트리얼솔루션즈     NaN
#
# [202 rows x 2 columns]

# %%
a = returns_df.loc[returns_df["Ticker"] == "카카오"]
a
# Out:
#     Ticker  Return
# 111    카카오   1.778

# %%
driver.quit()

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains

# 페이지 끝까지 스크롤
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)  # 페이지가 로드되도록 대기
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# 기사 제목, 날짜, 스크립트 크롤링
titles = driver.find_elements(By.CSS_SELECTOR, ".news_tit")  # 기사 제목
dates = driver.find_elements(By.CSS_SELECTOR, ".info_group > span")  # 기사 날짜
scripts = driver.find_elements(By.CSS_SELECTOR, ".dsc_txt_wrap")  # 기사 요약

# 데이터 저장
data = []
for title, date, script in zip(titles, dates, scripts):
    data.append({
        "Title": title.text,
        "Date": date.text,
        "Description": script.text
    })

# 데이터프레임 생성
df = pd.DataFrame(data)
df
# Out:
#                                         Title         Date  \
# 0    [속보] 우크라 "러, 지난해 12월부터 北탄도미사일 최소 24발 발사"  2024.02.16.
# 1   [속보] 美 "러시아 겨냥 500여개 신규 제재"…나발니 사망·우크라 전쟁  2024.02.23.
# 2  [속보] 젤렌스키 "우크라 군인 3만1000명 사망"... 전쟁 후 첫 언급  2024.02.26.
#
#                                          Description
# 0  우크라이나가 지난해 12월 30일 이후 러시아가 발사한 탄도미사일 중 최소 24발이...
# 1  미국이 러시아의 우크라이나 침공 2주년을 맞아 러시아에 대규모 제재를 부과했다. 특...
# 2  러시아의 우크라이나 침공 2년, 우크라이나와 이웃국가의 삶과 변화를 들여다봤다. 볼...
